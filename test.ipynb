# %%
from ipywidgets import widgets  

# Create text widget for output
prompt_RUNID = widgets.Text(description="RUNID: ")

# %%
prompt_RUNID
# Out:
# Text(value='sdrgdafg', description='RUNID: ')

# %%
# prompt_RUNID.value
# Out:
# 'jasdfasdf'

# %%
uppercase_string = prompt_RUNID.value.upper()
print(uppercase_string)
# Out:
# SDRGDAFG

# %%
# Out:
# HGCF
